# %% [markdown]
# ## binary Tress
# Fully binary trees -- all the nodes has either 2 or 0 nodes<br>
# Complete BT  -- last nodes has either 2 or 0 but has to be completed from left<br>
# Perfect BT   -- at the given level all are filled, completed<br>
# Balanced Binary tress -- Height can be maximum of log(N), N=number of nodes<br>
# Degeerate Tree -- where tree is growining only on one side<br>

# %% [markdown]
# Preorder --> node left right <br>
# Post order--> left right node <br>
# Inorder --> left node right <br>

# %% [markdown]
# ### Preorder Traversal

# %%
# Python program for preorder traversals

# Structure of a Binary Tree Node
class Node:
    def __init__(self, v):
        self.data = v
        self.left = None
        self.right = None

# Function to print preorder traversal
def printPreorder(node):
    if node is None:
        return

    # Deal with the node
    print(node.data, end=' ')

    # Recur on left subtree
    printPreorder(node.left)

    # Recur on right subtree
    printPreorder(node.right)


# Driver code
if __name__ == '__main__':
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)
    root.right.right = Node(6)

    # Function call
    print("Preorder traversal of binary tree is:")
    printPreorder(root)
# Out:
# Preorder traversal of binary tree is:
# 1 2 4 5 3 6

# %%
# Python program for Postorder traversals

# Structure of a Binary Tree Node
class Node:
    def __init__(self, v):
        self.data = v
        self.left = None
        self.right = None

# Function to print preorder traversal
def printPostorder(node):
    if node is None:
        return

    # Deal with the node
    

    # Recur on left subtree
    printPostorder(node.left)

    # Recur on right subtree
    printPostorder(node.right)
    print(node.data, end=' ')

# Driver code
if __name__ == '__main__':
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)
    root.right.right = Node(6)

    # Function call
    print("Postorder traversal of binary tree is:")
    printPostorder(root)
# Out:
# Postorder traversal of binary tree is:
# 4 5 2 6 3 1

# %%
# Python program for Inorder traversals

# Structure of a Binary Tree Node
class Node:
    def __init__(self, v):
        self.data = v
        self.left = None
        self.right = None

# Function to print preorder traversal
def printInorder(node):
    if node is None:
        return

    # Deal with the node
    

    # Recur on left subtree
    printInorder(node.left)
    print(node.data, end=' ')
    # Recur on right subtree
    printInorder(node.right)
    

# Driver code
if __name__ == '__main__':
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)
    root.right.right = Node(6)

    # Function call
    print("Inorder traversal of binary tree is:")
    printInorder(root)
# Out:
# Inorder traversal of binary tree is:
# 4 2 5 1 3 6

# %%
class Node:
    def __init__(self,value):
        self.value =value
        self.left =None
        self.right =None
        
        
def inorder_rinting(Node):
    
    if Node is None:
        return None
    inorder_rinting(Node.left)
    print(Node.value)
    inorder_rinting(Node.right)
    
    
    
    
    
if __name__=="__main__":
    root=Node(1)
    root.left =Node(2)
    root.right =Node(3)
    root.left.left =Node(4)
    root.left.right =Node(5)
    root.right.right =Node(6)
#     root.right =Node(3)

    inorder_rinting(root)
# Out:
# 4
# 2
# 5
# 1
# 3
# 6

# %% [markdown]
# ### level order Traversal : BFS

# %%
a=[]
a.append([])
print(a)
a[0].extend([5,5])
a
# Out:
# [[]]
# [[5, 5]]

# %%
import collections

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def levelorder(root):
    if root is None:
        return []
    
    q = collections.deque()
    res = []
    
    q.append(root)
    currlevel = 0
    
    while q:
        print("Queue at the start of while loop:", [node.value for node in q])
        print("Res at the start of while loop:", res)
        len_q = len(q)
        res.append([])
        
        for _ in range(len_q):
            node = q.popleft()  # Get element from queue
            print("Processing Node:", node.value)  # Print each element
            res[currlevel].append(node.value)

            if node.left is not None:
                q.append(node.left)

            if node.right is not None:
                q.append(node.right)
                
        currlevel += 1
    
    return res
            
if __name__ == "__main__":
    # Create binary tree
    #      1         
    #     / \       
    #    3   2      
    #          \   
    #           4 
    #          /  \
    #         6    5
    root = Node(1)
    root.left = Node(3)
    root.right = Node(2)
    root.right.right = Node(4)
    root.right.right.left = Node(6)
    root.right.right.right = Node(5)

    # Perform level order traversal
    res = levelorder(root)
    print("Final Level Order Traversal:", res)
# Out:
# Queue at the start of while loop: [1]
# Res at the start of while loop: []
# Processing Node: 1
# Queue at the start of while loop: [3, 2]
# Res at the start of while loop: [[1]]
# Processing Node: 3
# Processing Node: 2
# Queue at the start of while loop: [4]
# Res at the start of while loop: [[1], [3, 2]]
# Processing Node: 4
# Queue at the start of while loop: [6, 5]
# Res at the start of while loop: [[1], [3, 2], [4]]
# Processing Node: 6
# Processing Node: 5
# Final Level Order Traversal: [[1], [3, 2], [4], [6, 5]]

# %%
#using the Queue


from collections import deque

class Node:
    def __init__(self, value):
        self.data = value
        self.left = None
        self.right = None

def levelOrder(root):
    if root is None:
        return []

    # Create an empty queue for level order traversal
    q = deque()
    res = []

    # Enqueue Root
    q.append(root)
    currLevel = 0

    while q:
        len_q = len(q)
        res.append([])

        for _ in range(len_q):
            # Add front of queue and remove it from queue
            node = q.popleft()
            res[currLevel].append(node.data)

            # Enqueue left child
            if node.left is not None:
                q.append(node.left)

            # Enqueue right child
            if node.right is not None:
                q.append(node.right)
        currLevel += 1

    return res
      
if __name__ == "__main__":
    # Create binary tree
    #      1         
    #     / \       
    #    3   2      
    #          \   
    #           4 
    #          /  \
    #         6    5
    root = Node(1)
    root.left = Node(3)
    root.right = Node(2)
    root.right.right = Node(4)
    root.right.right.left = Node(6)
    root.right.right.right = Node(5)

    # Perform level order traversal
    res = levelOrder(root)

    # Print the result
    for level in res:
        for data in level:
            print(data, end=" ")
# Out:
# 1 3 2 4 6 5

# %%
# Recursive Python program for level order traversal of Binary Tree

class Node:
    def __init__(self, value):
        self.data = value
        self.left = None
        self.right = None

# Helper function for recursive level order traversal
def levelOrderRec(root, level, res):
    if not root:
        return

    # Add a new level to the result if needed
    if len(res) <= level:
        res.append([])

    # Add current node's data to its corresponding level
    res[level].append(root.data)
    print(root.data,"root.data")
    # Recur for left and right children
    levelOrderRec(root.left, level + 1, res)
    levelOrderRec(root.right, level + 1, res)

# Function to perform level order traversal
def levelOrder(root):
    res = []
    levelOrderRec(root, 0, res)
    return res
      
if __name__ == "__main__":
    # Create binary tree
      #      1         
    #     / \       
    #    3   2      
    #          \   
    #           4 
    #          /  \
    #         6    5  132465
    root = Node(1)
    root.left = Node(3)
    root.right = Node(2)
    root.right.right = Node(4)
    root.right.right.left = Node(6)
    root.right.right.right = Node(5)

    # Perform level order traversal
    res = levelOrder(root)

    # Print the result
    for level in res:
        for data in level:
            print(data, end=" ")
# Out:
# 1 root.data
# 3 root.data
# 2 root.data
# 4 root.data
# 6 root.data
# 5 root.data
# 1 3 2 4 6 5

# %%
class Node:
    def __init__(self,value):
        self.value  = value
        self.left = None
        self.right = None
        
    
def level_order_printing(Node):
    
    if Node is None:
        return None
    level_order_printing(Node.left)
    print(Node.value)
    inorder_rinting(Node.right)

# %% [markdown]
# ### DFS

# %% [markdown]
# Depth-First Search (DFS) can be classified into three main types based on the order in which the nodes are visited:<br>
#
# <b>Pre-order Traversal</b>: Visits the root node first, then recursively explores the left and right subtrees.<br>
# <b>In-order Traversal</b>: Explores the left subtree first, then visits the root, and finally the right subtree.<br>
# <b>Post-order Traversal</b>: Explores the left and right subtrees first, then visits the root node.<br>
