# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import OneHotEncoder,StandardScaler

from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline   
from sklearn.preprocessing import MinMaxScaler

# %%
data = {
    'review_text': ['great service', 'bad food', 'amazing experience', 'terrible', 'loved it'],
    'location': ['NYC', 'LA', 'NYC', 'CHI', 'LA'], # Categorical
    'age': [25, 45, 30, 50, 22],                  # Numerical
    'satisfied': [1, 0, 1, 0, 1]                  # Target
}
df = pd.DataFrame(data)
df
# Out:
#           review_text location  age  satisfied
# 0       great service      NYC   25          1
# 1            bad food       LA   45          0
# 2  amazing experience      NYC   30          1
# 3            terrible      CHI   50          0
# 4            loved it       LA   22          1

# %%
preprocessor = ColumnTransformer(
transformers=[
(    'text',CountVectorizer(),'review_text'),
    ('cat',OneHotEncoder(),['location']),
    ('num',MinMaxScaler(),['age'])
    
]
)

# %%
pipeline = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('classifier',MultinomialNB())
    ])

# %%
X=df.drop('satisfied',axis=1)
y=df['satisfied']
pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('text', CountVectorizer(),
#                                                   'review_text'),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['location']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['age'])])),
#                 ('classifier', MultinomialNB())])

# %%
new_data = pd.DataFrame({'review_text': ['great food'], 'location': ['NYC'], 'age': [30]})

prediction = pipeline.predict(new_data)
prediction
# Out:
# array([1])
